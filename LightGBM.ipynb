# %% [markdown]
# # Light GBM

# %%
# !pip install lightgbm
# Out:
# Collecting lightgbm
#   Downloading lightgbm-3.3.5-py3-none-manylinux1_x86_64.whl (2.0 MB)
#      |████████████████████████████████| 2.0 MB 3.3 MB/s eta 0:00:01
# Requirement already satisfied: numpy in /home/suedagulgun/virenvs/text-gen/lib/python3.8/site-packages (from lightgbm) (1.22.4)
# Requirement already satisfied: scikit-learn!=0.22.0 in /home/suedagulgun/virenvs/text-gen/lib/python3.8/site-packages (from lightgbm) (1.2.1)
# Requirement already satisfied: wheel in /home/suedagulgun/virenvs/text-gen/lib/python3.8/site-packages (from lightgbm) (0.38.4)
# Requirement already satisfied: scipy in /home/suedagulgun/virenvs/text-gen/lib/python3.8/site-packages (from lightgbm) (1.10.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/suedagulgun/virenvs/text-gen/lib/python3.8/site-packages (from scikit-learn!=0.22.0->lightgbm) (3.1.0)
# Requirement already satisfied: joblib>=1.1.1 in /home/suedagulgun/virenvs/text-gen/lib/python3.8/site-packages (from scikit-learn!=0.22.0->lightgbm) (1.2.0)
# Installing collected packages: lightgbm
# Successfully installed lightgbm-3.3.5

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import GridSearchCV
from lightgbm import LGBMRegressor

from warnings import filterwarnings
filterwarnings('ignore')

# %%
hit = pd.read_csv("Hitters.csv")
df = hit.copy()
df = df.dropna()
dms = pd.get_dummies(df[['League', 'Division', 'NewLeague']])
y = df["Salary"]
X_ = df.drop(['Salary', 'League', 'Division', 'NewLeague'], axis=1).astype('float64')
X = pd.concat([X_, dms[['League_N', 'Division_W', 'NewLeague_N']]], axis=1)
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=0.25,
                                                    random_state=42)

# %%
#conda install -c conda-forge lightgbm

# %%
lgbm = LGBMRegressor()
lgbm_model = lgbm.fit(X_train, y_train)

# %% [markdown]
# ## Tahmin

# %%
y_pred = lgbm_model.predict(X_test,
                            num_iteration = lgbm_model.best_iteration_)

# %%
np.sqrt(mean_squared_error(y_test, y_pred))
# Out:
# 363.8712087611089

# %% [markdown]
# ## Model Tuning

# %%
lgbm_model
# Out:
# LGBMRegressor()

# %%
lgbm_grid = {
    'colsample_bytree': [0.4, 0.5,0.6,0.9,1],
    'learning_rate': [0.01, 0.1, 0.5,1],
    'n_estimators': [20, 40, 100, 200, 500,1000],
    'max_depth': [1,2,3,4,5,6,7,8] }

lgbm = LGBMRegressor()
lgbm_cv_model = GridSearchCV(lgbm, lgbm_grid, cv=10, n_jobs = -1, verbose = 2)

# %%
lgbm_cv_model.fit(X_train, y_train)
# Out:
# Fitting 10 folds for each of 960 candidates, totalling 9600 fits
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=1, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=1, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=1, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=1, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=1, n_estimators=1000; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=2, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=2, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=2, n_estimators=1000; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=2, n_estimators=1000; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=5, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=5, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=5, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=5, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=5, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=5, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=5, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=5, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=5, n_estimators=1000; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=5, n_estimators=1000; total time=   0.3s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=5, n_estimators=1000; total time=   0.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=5, n_estimators=1000; total time=   0.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=1, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=1, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=1, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=1, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=1, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=1, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=1, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=1, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=1, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=1, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=1, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=1, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=1, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=1, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=1, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=1, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=1, n_estimators=500; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=1, n_estimators=500; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=1, n_estimators=500; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=1, n_estimators=500; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=1, n_estimators=500; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=1, n_estimators=500; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=1, n_estimators=500; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=1, n_estimators=500; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=3, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=3, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=3, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=3, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=3, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=3, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=3, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=3, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=3, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=3, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=3, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=3, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=3, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=3, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=3, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=3, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=1, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=1, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=1, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=1, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=1, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=1, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=1, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=1, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=1, n_estimators=500; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=1, n_estimators=1000; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=2, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=2, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=2, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=2, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=2, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=2, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=3, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=3, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=3, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=3, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=3, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=3, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=3, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=3, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=5, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=5, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=5, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=5, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=5, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=5, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=5, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=5, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=7, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=7, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=7, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=7, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=7, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=7, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=7, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=7, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=7, n_estimators=1000; total time=   0.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=7, n_estimators=1000; total time=   0.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=7, n_estimators=1000; total time=   0.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=7, n_estimators=1000; total time=   0.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=2, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=2, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=2, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=2, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=2, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=2, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=2, n_estimators=1000; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=2, n_estimators=1000; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=5, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=5, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=5, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=5, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=5, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=5, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=5, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=5, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=5, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=5, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=5, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=5, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=5, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=5, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=5, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=5, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=1, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=1, n_estimators=1000; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=2, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=2, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=2, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=2, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=3, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=3, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=3, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=3, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=3, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=3, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=3, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=3, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=3, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=3, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=3, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=3, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=5, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=5, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=5, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=5, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=5, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=5, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=5, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=5, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=7, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=7, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=7, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=7, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=7, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=7, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=7, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=7, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=7, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=7, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=7, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=7, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=7, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=7, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=7, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=7, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=7, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=7, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=7, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=7, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=7, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=7, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=7, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=7, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=2, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=2, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=2, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=2, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=2, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=2, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=2, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=2, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=2, n_estimators=1000; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=2, n_estimators=1000; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=2, n_estimators=1000; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=2, n_estimators=1000; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=2, n_estimators=1000; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=2, n_estimators=1000; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=2, n_estimators=1000; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=2, n_estimators=1000; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=7, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=7, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=7, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=1, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=2, n_estimators=1000; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=2, n_estimators=1000; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=500; total time=   0.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=7, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=7, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=7, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=7, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=7, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=7, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=7, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=7, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=2, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=2, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=2, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=2, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=2, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=2, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=2, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=2, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=3, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=3, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=3, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=3, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=3, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=3, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=3, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=3, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=5, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=5, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=5, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=5, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=5, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=5, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=5, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=5, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=500; total time=   0.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=1, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=1, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=1, n_estimators=500; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=1, n_estimators=1000; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=2, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=2, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=2, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=2, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=2, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=2, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=2, n_estimators=1000; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=2, n_estimators=1000; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=5, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=5, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=5, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=5, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=5, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=5, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=5, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=5, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=5, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=5, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=5, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=5, n_estimators=500; total time=   0.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=5, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=5, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=5, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=5, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=1000; total time=   0.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=1000; total time=   0.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=8, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=1, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=1, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=1, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=1, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=1, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=1, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=1, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=1, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=1, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=1, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=1, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=1, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=1, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=1, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=1, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=1, n_estimators=1000; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=2, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=2, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=2, n_estimators=1000; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=2, n_estimators=1000; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=3, n_estimators=1000; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=3, n_estimators=1000; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=3, n_estimators=1000; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=3, n_estimators=1000; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=8, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=1, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=1, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=1, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=1, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=1, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=1, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=1, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=1, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=2, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=2, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=2, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=2, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=2, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=2, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=2, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=2, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=2, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=2, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=2, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=2, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=2, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=2, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=2, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=2, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=1000; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=1000; total time=   0.2s
# ...
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=7, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=7, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=7, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=8, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=8, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=8, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=8, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=8, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=8, n_estimators=500; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=8, n_estimators=1000; total time=   0.4s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=8, n_estimators=1000; total time=   0.3s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=4, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=4, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=4, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=4, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=4, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=4, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=4, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=4, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=5, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=5, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=5, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=5, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=5, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=5, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=5, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=5, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=8, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=8, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=8, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=8, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=8, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=8, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=8, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=8, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=8, n_estimators=1000; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=8, n_estimators=1000; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=8, n_estimators=1000; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=8, n_estimators=1000; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=8, n_estimators=1000; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=8, n_estimators=1000; total time=   0.3s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=8, n_estimators=1000; total time=   0.3s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=8, n_estimators=1000; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.5, max_depth=6, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=0.5, max_depth=6, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=0.5, max_depth=6, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=0.5, max_depth=6, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=0.5, max_depth=6, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=0.5, max_depth=6, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=0.5, max_depth=6, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=0.5, max_depth=6, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=0.5, max_depth=7, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.5, max_depth=7, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=0.5, max_depth=7, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=0.5, max_depth=7, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=0.5, max_depth=7, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=0.5, max_depth=7, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=0.5, max_depth=7, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.5, max_depth=7, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=0.5, max_depth=8, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.5, max_depth=8, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.5, max_depth=8, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.5, max_depth=8, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.5, max_depth=8, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.5, max_depth=8, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.5, max_depth=8, n_estimators=1000; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.5, max_depth=8, n_estimators=1000; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=1, max_depth=4, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=1, max_depth=4, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=1, max_depth=4, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=1, max_depth=4, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=1, max_depth=4, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=1, max_depth=4, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=1, max_depth=4, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=1, max_depth=4, n_estimators=40; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=1, max_depth=4, n_estimators=1000; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=7, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=7, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=7, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=7, n_estimators=1000; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=7, n_estimators=1000; total time=   0.3s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=7, n_estimators=1000; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=7, n_estimators=1000; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=8, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=8, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=8, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=8, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=0.5, max_depth=3, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=0.5, max_depth=3, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=0.5, max_depth=3, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=0.5, max_depth=3, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=0.5, max_depth=3, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=0.5, max_depth=3, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=0.5, max_depth=3, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=0.5, max_depth=3, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=0.5, max_depth=3, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=0.5, max_depth=3, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=0.5, max_depth=3, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=0.5, max_depth=3, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=0.5, max_depth=3, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=0.5, max_depth=3, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.5, max_depth=3, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=0.5, max_depth=3, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=0.5, max_depth=4, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.5, max_depth=4, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.5, max_depth=4, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.5, max_depth=4, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.5, max_depth=4, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.5, max_depth=4, n_estimators=500; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.5, max_depth=4, n_estimators=1000; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.5, max_depth=4, n_estimators=1000; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.5, max_depth=7, n_estimators=1000; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.5, max_depth=7, n_estimators=1000; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.5, max_depth=7, n_estimators=1000; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.5, max_depth=7, n_estimators=1000; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.5, max_depth=8, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=0.5, max_depth=8, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=0.5, max_depth=8, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=0.5, max_depth=8, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=1, max_depth=2, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=1, max_depth=2, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=1, max_depth=2, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=1, max_depth=2, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=1, max_depth=2, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=1, max_depth=2, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=1, max_depth=2, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=1, max_depth=2, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=1, max_depth=3, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=1, max_depth=3, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=1, max_depth=3, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=1, max_depth=3, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=1, max_depth=3, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=1, max_depth=3, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=1, max_depth=3, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=1, max_depth=3, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=1, max_depth=3, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=1, max_depth=3, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=1, max_depth=3, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=1, max_depth=3, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=1, max_depth=3, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=1, max_depth=3, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=1, max_depth=3, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=1, max_depth=3, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=1, max_depth=5, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=1, max_depth=5, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=1, max_depth=5, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=1, max_depth=5, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=1, max_depth=5, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=1, max_depth=5, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=1, max_depth=5, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=1, max_depth=5, n_estimators=20; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=1, max_depth=5, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=1, max_depth=5, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=1, max_depth=5, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=1, max_depth=5, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=1, max_depth=5, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=1, max_depth=5, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=1, max_depth=5, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=1, max_depth=5, n_estimators=200; total time=   0.0s
# [CV] END colsample_bytree=1, learning_rate=1, max_depth=6, n_estimators=20; total time=   0.0s
# GridSearchCV(cv=10, estimator=LGBMRegressor(), n_jobs=-1,
#              param_grid={'colsample_bytree': [0.4, 0.5, 0.6, 0.9, 1],
#                          'learning_rate': [0.01, 0.1, 0.5, 1],
#                          'max_depth': [1, 2, 3, 4, 5, 6, 7, 8],
#                          'n_estimators': [20, 40, 100, 200, 500, 1000]},
#              verbose=2)

# %%
lgbm_cv_model.best_params_
# Out:
# {'colsample_bytree': 0.5,
#  'learning_rate': 0.1,
#  'max_depth': 6,
#  'n_estimators': 20}

# %%
lgbm_tuned = LGBMRegressor(learning_rate = 0.1,
                           max_depth = 6,
                           n_estimators = 20,
                          colsample_bytree = 0.5)

lgbm_tuned = lgbm_tuned.fit(X_train,y_train)

# %%
y_pred = lgbm_tuned.predict(X_test)

# %%
np.sqrt(mean_squared_error(y_test, y_pred))
# Out:
# 375.6085209015434
