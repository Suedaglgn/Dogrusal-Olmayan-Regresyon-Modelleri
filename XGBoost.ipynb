# %% [markdown]
# # XGBoost

# %%
# !pip install xgboost
# Out:
# Collecting xgboost
#   Downloading xgboost-1.7.4-py3-none-manylinux2014_x86_64.whl (193.6 MB)
#      |████████████████████████████████| 193.6 MB 81 kB/s s eta 0:00:01
# Requirement already satisfied: numpy in /home/suedagulgun/virenvs/text-gen/lib/python3.8/site-packages (from xgboost) (1.22.4)
# Requirement already satisfied: scipy in /home/suedagulgun/virenvs/text-gen/lib/python3.8/site-packages (from xgboost) (1.10.0)
# Installing collected packages: xgboost
# Successfully installed xgboost-1.7.4
# Requirement already satisfied: xgboost in /home/suedagulgun/virenvs/text-gen/lib/python3.8/site-packages (1.7.4)
# Requirement already satisfied: numpy in /home/suedagulgun/virenvs/text-gen/lib/python3.8/site-packages (from xgboost) (1.22.4)
# Requirement already satisfied: scipy in /home/suedagulgun/virenvs/text-gen/lib/python3.8/site-packages (from xgboost) (1.10.0)

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import GridSearchCV
import xgboost as xgb
from xgboost import XGBRegressor

from warnings import filterwarnings
filterwarnings('ignore')

# %%
hit = pd.read_csv("Hitters.csv")
df = hit.copy()
df = df.dropna()
dms = pd.get_dummies(df[['League', 'Division', 'NewLeague']])
y = df["Salary"]
X_ = df.drop(['Salary', 'League', 'Division', 'NewLeague'], axis=1).astype('float64')
X = pd.concat([X_, dms[['League_N', 'Division_W', 'NewLeague_N']]], axis=1)
X_train, X_test, y_train, y_test = train_test_split(X, y,
                                                    test_size=0.25,
                                                    random_state=42)

# %%
DM_train = xgb.DMatrix(data = X_train, label = y_train)
DM_test = xgb.DMatrix(data = X_test, label = y_test)

# %%
xgb_model = XGBRegressor().fit(X_train, y_train)

# %% [markdown]
# ## Tahmin

# %%
y_pred = xgb_model.predict(X_test)
np.sqrt(mean_squared_error(y_test, y_pred))
# Out:
# 355.46515176059927

# %% [markdown]
# ## Model Tuning

# %%
xgb_model
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, gpu_id=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              n_estimators=100, n_jobs=None, num_parallel_tree=None,
#              predictor=None, random_state=None, ...)

# %%
xgb_grid = {
     'colsample_bytree': [0.4, 0.5,0.6,0.9,1],
     'n_estimators':[100, 200, 500, 1000],
     'max_depth': [2,3,4,5,6],
     'learning_rate': [0.1, 0.01, 0.5]
}

# %%
xgb = XGBRegressor()

xgb_cv = GridSearchCV(xgb,
                      param_grid = xgb_grid,
                      cv = 10,
                      n_jobs = -1,
                      verbose = 2)
xgb_cv.fit(X_train, y_train)
# Out:
# Fitting 10 folds for each of 300 candidates, totalling 3000 fits
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=2, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=2, n_estimators=500; total time=   0.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=2, n_estimators=1000; total time=   0.5s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=3, n_estimators=500; total time=   0.3s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=3, n_estimators=1000; total time=   0.4s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=500; total time=   0.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=5, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=5, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=5, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=5, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=5, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=5, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=5, n_estimators=1000; total time=   0.4s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=1000; total time=   0.4s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=2, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=2, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=2, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=2, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=2, n_estimators=500; total time=   0.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=2, n_estimators=1000; total time=   0.3s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=3, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=3, n_estimators=1000; total time=   0.4s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=500; total time=   0.3s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=1000; total time=   0.6s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=5, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=5, n_estimators=500; total time=   0.4s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=500; total time=   0.3s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=1000; total time=   0.7s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=2, n_estimators=500; total time=   0.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=3, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=3, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=3, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=3, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=3, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=3, n_estimators=500; total time=   0.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=3, n_estimators=1000; total time=   0.4s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=4, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=4, n_estimators=500; total time=   0.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=4, n_estimators=1000; total time=   0.3s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=5, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=5, n_estimators=1000; total time=   0.3s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=6, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=6, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=6, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=6, n_estimators=1000; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=2, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=2, n_estimators=500; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=2, n_estimators=1000; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=500; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=4, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=4, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=4, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=4, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=4, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=4, n_estimators=500; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=4, n_estimators=1000; total time=   0.6s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=500; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=1000; total time=   0.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=6, n_estimators=200; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=6, n_estimators=500; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=2, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=2, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=2, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=2, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=2, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=2, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=2, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=2, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=2, n_estimators=500; total time=   0.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=2, n_estimators=1000; total time=   0.4s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=3, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=3, n_estimators=500; total time=   0.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=3, n_estimators=1000; total time=   0.4s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=500; total time=   0.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=1000; total time=   0.5s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=5, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=5, n_estimators=500; total time=   0.3s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=5, n_estimators=1000; total time=   0.4s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=500; total time=   0.3s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=1000; total time=   0.4s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=2, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=2, n_estimators=500; total time=   0.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=3, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=3, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=3, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=3, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=3, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=3, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=3, n_estimators=500; total time=   0.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=1000; total time=   0.6s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=5, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=5, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=5, n_estimators=500; total time=   0.3s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=5, n_estimators=1000; total time=   0.7s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=500; total time=   0.4s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=1000; total time=   0.7s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=2, n_estimators=500; total time=   0.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=2, n_estimators=1000; total time=   0.4s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=3, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=3, n_estimators=500; total time=   0.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=4, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=4, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=4, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=4, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=4, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=4, n_estimators=500; total time=   0.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=5, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=5, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=5, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=5, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=5, n_estimators=500; total time=   0.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=5, n_estimators=1000; total time=   0.3s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=6, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=6, n_estimators=500; total time=   0.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=6, n_estimators=1000; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=2, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=2, n_estimators=1000; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=500; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=1000; total time=   0.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=4, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=4, n_estimators=500; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=500; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=6, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=6, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=6, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=6, n_estimators=200; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=6, n_estimators=200; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=6, n_estimators=1000; total time=   0.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=2, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=2, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=2, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=2, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=2, n_estimators=500; total time=   0.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=2, n_estimators=1000; total time=   0.4s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=3, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=3, n_estimators=500; total time=   0.3s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=500; total time=   0.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=1000; total time=   0.5s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=5, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=5, n_estimators=500; total time=   0.3s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=5, n_estimators=1000; total time=   0.4s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=500; total time=   0.3s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=2, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=2, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=2, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=2, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=2, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=2, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=2, n_estimators=500; total time=   0.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=2, n_estimators=1000; total time=   0.3s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=3, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=3, n_estimators=500; total time=   0.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=3, n_estimators=1000; total time=   0.4s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=500; total time=   0.3s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=1000; total time=   0.5s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=5, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=5, n_estimators=500; total time=   0.4s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=5, n_estimators=1000; total time=   0.7s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=1000; total time=   0.7s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=2, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=2, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=2, n_estimators=500; total time=   0.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=2, n_estimators=1000; total time=   0.4s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=3, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=3, n_estimators=500; total time=   0.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=3, n_estimators=1000; total time=   0.4s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=4, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=4, n_estimators=500; total time=   0.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=4, n_estimators=1000; total time=   0.3s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=5, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=5, n_estimators=500; total time=   0.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=5, n_estimators=1000; total time=   0.3s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=6, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=6, n_estimators=1000; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=2, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=2, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=2, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=2, n_estimators=500; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=2, n_estimators=1000; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=1000; total time=   0.6s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=4, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=4, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=4, n_estimators=1000; total time=   0.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=200; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=500; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=6, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=6, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=6, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=6, n_estimators=200; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=6, n_estimators=200; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=6, n_estimators=500; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=2, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=2, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=2, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=2, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=2, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=2, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=2, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=2, n_estimators=1000; total time=   0.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=3, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=3, n_estimators=500; total time=   0.3s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=2, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=2, n_estimators=500; total time=   0.3s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=3, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=3, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=3, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=3, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=3, n_estimators=500; total time=   0.3s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=500; total time=   0.3s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=1000; total time=   0.5s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=5, n_estimators=500; total time=   0.3s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=500; total time=   0.3s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=1000; total time=   0.4s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=2, n_estimators=500; total time=   0.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=2, n_estimators=1000; total time=   0.4s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=3, n_estimators=500; total time=   0.3s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=500; total time=   0.3s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=5, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=5, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=5, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=5, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=5, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=5, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=5, n_estimators=500; total time=   0.4s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=5, n_estimators=1000; total time=   0.7s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=500; total time=   0.3s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=1000; total time=   0.8s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=2, n_estimators=500; total time=   0.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=3, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=3, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=3, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=3, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=3, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=3, n_estimators=1000; total time=   0.3s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=4, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=4, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=4, n_estimators=500; total time=   0.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=4, n_estimators=1000; total time=   0.3s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=5, n_estimators=200; total time=   0.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=5, n_estimators=500; total time=   0.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=6, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=6, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=6, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=6, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=6, n_estimators=500; total time=   0.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=6, n_estimators=1000; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=2, n_estimators=500; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=2, n_estimators=1000; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=1000; total time=   0.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=4, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=4, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=4, n_estimators=500; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=4, n_estimators=1000; total time=   0.6s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=500; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=1000; total time=   0.6s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=6, n_estimators=500; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=6, n_estimators=1000; total time=   0.6s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=2, n_estimators=500; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=3, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=3, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=3, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=3, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=3, n_estimators=500; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=3, n_estimators=1000; total time=   0.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=4, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=2, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=2, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=2, n_estimators=500; total time=   0.3s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=2, n_estimators=1000; total time=   0.4s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=3, n_estimators=500; total time=   0.3s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=3, n_estimators=1000; total time=   0.4s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=500; total time=   0.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=1000; total time=   0.5s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=5, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=5, n_estimators=500; total time=   0.3s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=5, n_estimators=1000; total time=   0.4s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=500; total time=   0.3s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=1000; total time=   0.4s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=2, n_estimators=1000; total time=   0.3s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=3, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=3, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=3, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=3, n_estimators=500; total time=   0.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=3, n_estimators=1000; total time=   0.4s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=500; total time=   0.3s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=1000; total time=   0.6s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=5, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=5, n_estimators=500; total time=   0.4s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=200; total time=   0.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=500; total time=   0.4s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=2, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=2, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=2, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=2, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=2, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=2, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=2, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=2, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=2, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=2, n_estimators=500; total time=   0.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=2, n_estimators=1000; total time=   0.4s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=3, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=3, n_estimators=500; total time=   0.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=3, n_estimators=1000; total time=   0.4s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=4, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=4, n_estimators=500; total time=   0.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=5, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=5, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=5, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=5, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=5, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=5, n_estimators=500; total time=   0.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=5, n_estimators=1000; total time=   0.3s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=6, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=6, n_estimators=500; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=2, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=2, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=2, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=2, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=2, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=2, n_estimators=500; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=2, n_estimators=1000; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=500; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=1000; total time=   0.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=4, n_estimators=500; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=4, n_estimators=1000; total time=   0.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=200; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=500; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=1000; total time=   0.6s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=6, n_estimators=500; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=6, n_estimators=1000; total time=   0.6s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=2, n_estimators=500; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=2, n_estimators=1000; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=3, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=3, n_estimators=1000; total time=   0.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=4, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=4, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=4, n_estimators=500; total time=   0.3s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=2, n_estimators=100; total time=   0.0s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=2, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=2, n_estimators=200; total time=   0.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=2, n_estimators=500; total time=   0.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=2, n_estimators=1000; total time=   0.4s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=3, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=3, n_estimators=500; total time=   0.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=3, n_estimators=1000; total time=   0.4s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=4, n_estimators=1000; total time=   0.4s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=5, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=5, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=5, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=5, n_estimators=1000; total time=   0.4s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=500; total time=   0.3s
# [CV] END colsample_bytree=0.4, learning_rate=0.1, max_depth=6, n_estimators=1000; total time=   0.4s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=2, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=2, n_estimators=500; total time=   0.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=2, n_estimators=1000; total time=   0.3s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=3, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=3, n_estimators=1000; total time=   0.4s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=4, n_estimators=1000; total time=   0.6s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=5, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=5, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=5, n_estimators=500; total time=   0.4s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=5, n_estimators=1000; total time=   0.6s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.01, max_depth=6, n_estimators=1000; total time=   0.7s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=2, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=2, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=2, n_estimators=500; total time=   0.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=2, n_estimators=1000; total time=   0.4s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=3, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=3, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=3, n_estimators=500; total time=   0.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=3, n_estimators=1000; total time=   0.3s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=4, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=4, n_estimators=500; total time=   0.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=4, n_estimators=1000; total time=   0.4s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=5, n_estimators=500; total time=   0.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=5, n_estimators=1000; total time=   0.4s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=6, n_estimators=500; total time=   0.2s
# [CV] END colsample_bytree=0.4, learning_rate=0.5, max_depth=6, n_estimators=1000; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=2, n_estimators=500; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=500; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=3, n_estimators=1000; total time=   0.6s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=4, n_estimators=500; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=200; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=500; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=5, n_estimators=1000; total time=   0.6s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=6, n_estimators=500; total time=   0.3s
# [CV] END colsample_bytree=0.5, learning_rate=0.1, max_depth=6, n_estimators=1000; total time=   0.5s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=2, n_estimators=500; total time=   0.2s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=2, n_estimators=1000; total time=   0.4s
# [CV] END colsample_bytree=0.5, learning_rate=0.01, max_depth=3, n_estimators=200; total time=   0.1s
# ...
# [CV] END colsample_bytree=0.9, learning_rate=0.01, max_depth=4, n_estimators=1000; total time=   0.8s
# [CV] END colsample_bytree=0.9, learning_rate=0.01, max_depth=5, n_estimators=500; total time=   0.5s
# [CV] END colsample_bytree=0.9, learning_rate=0.01, max_depth=5, n_estimators=1000; total time=   1.0s
# [CV] END colsample_bytree=0.9, learning_rate=0.01, max_depth=6, n_estimators=200; total time=   0.2s
# [CV] END colsample_bytree=0.9, learning_rate=0.01, max_depth=6, n_estimators=1000; total time=   1.1s
# [CV] END colsample_bytree=0.9, learning_rate=0.5, max_depth=2, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.9, learning_rate=0.5, max_depth=2, n_estimators=500; total time=   0.2s
# [CV] END colsample_bytree=0.9, learning_rate=0.5, max_depth=2, n_estimators=500; total time=   0.3s
# [CV] END colsample_bytree=0.9, learning_rate=0.5, max_depth=2, n_estimators=1000; total time=   0.5s
# [CV] END colsample_bytree=0.9, learning_rate=0.5, max_depth=3, n_estimators=500; total time=   0.3s
# [CV] END colsample_bytree=0.9, learning_rate=0.5, max_depth=3, n_estimators=1000; total time=   0.4s
# [CV] END colsample_bytree=0.9, learning_rate=0.5, max_depth=4, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.9, learning_rate=0.5, max_depth=4, n_estimators=500; total time=   0.2s
# [CV] END colsample_bytree=0.9, learning_rate=0.5, max_depth=4, n_estimators=1000; total time=   0.4s
# [CV] END colsample_bytree=0.9, learning_rate=0.5, max_depth=5, n_estimators=200; total time=   0.2s
# [CV] END colsample_bytree=0.9, learning_rate=0.5, max_depth=5, n_estimators=1000; total time=   0.4s
# [CV] END colsample_bytree=0.9, learning_rate=0.5, max_depth=6, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.9, learning_rate=0.5, max_depth=6, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.9, learning_rate=0.5, max_depth=6, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.9, learning_rate=0.5, max_depth=6, n_estimators=500; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=2, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=2, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=2, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=2, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=2, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=2, n_estimators=500; total time=   0.3s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=2, n_estimators=1000; total time=   0.5s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=3, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=3, n_estimators=500; total time=   0.4s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=4, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=4, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=4, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=4, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=4, n_estimators=200; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=4, n_estimators=500; total time=   0.5s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=4, n_estimators=1000; total time=   0.8s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=5, n_estimators=500; total time=   0.5s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=5, n_estimators=1000; total time=   0.7s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=6, n_estimators=200; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=6, n_estimators=500; total time=   0.5s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=6, n_estimators=1000; total time=   0.7s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=2, n_estimators=500; total time=   0.3s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=2, n_estimators=1000; total time=   0.5s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=3, n_estimators=500; total time=   0.3s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=3, n_estimators=1000; total time=   0.8s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=4, n_estimators=200; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=4, n_estimators=500; total time=   0.4s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=4, n_estimators=1000; total time=   0.8s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=5, n_estimators=500; total time=   0.5s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=5, n_estimators=1000; total time=   1.0s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=6, n_estimators=200; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=6, n_estimators=500; total time=   0.6s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=6, n_estimators=1000; total time=   1.1s
# [CV] END colsample_bytree=1, learning_rate=0.5, max_depth=2, n_estimators=500; total time=   0.3s
# [CV] END colsample_bytree=1, learning_rate=0.5, max_depth=3, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.5, max_depth=3, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.5, max_depth=3, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.5, max_depth=3, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.5, max_depth=3, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.5, max_depth=3, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.5, max_depth=3, n_estimators=500; total time=   0.3s
# [CV] END colsample_bytree=1, learning_rate=0.5, max_depth=3, n_estimators=1000; total time=   0.4s
# [CV] END colsample_bytree=1, learning_rate=0.5, max_depth=4, n_estimators=200; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.5, max_depth=4, n_estimators=1000; total time=   0.5s
# [CV] END colsample_bytree=0.9, learning_rate=0.01, max_depth=2, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.9, learning_rate=0.01, max_depth=2, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.9, learning_rate=0.01, max_depth=2, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.9, learning_rate=0.01, max_depth=2, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.9, learning_rate=0.01, max_depth=2, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.9, learning_rate=0.01, max_depth=2, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.9, learning_rate=0.01, max_depth=2, n_estimators=200; total time=   0.2s
# [CV] END colsample_bytree=0.9, learning_rate=0.01, max_depth=2, n_estimators=500; total time=   0.3s
# [CV] END colsample_bytree=0.9, learning_rate=0.01, max_depth=2, n_estimators=1000; total time=   0.5s
# [CV] END colsample_bytree=0.9, learning_rate=0.01, max_depth=3, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.9, learning_rate=0.01, max_depth=3, n_estimators=500; total time=   0.3s
# [CV] END colsample_bytree=0.9, learning_rate=0.01, max_depth=4, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.9, learning_rate=0.01, max_depth=4, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.9, learning_rate=0.01, max_depth=4, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.9, learning_rate=0.01, max_depth=4, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.9, learning_rate=0.01, max_depth=4, n_estimators=200; total time=   0.2s
# [CV] END colsample_bytree=0.9, learning_rate=0.01, max_depth=4, n_estimators=500; total time=   0.4s
# [CV] END colsample_bytree=0.9, learning_rate=0.01, max_depth=4, n_estimators=1000; total time=   0.8s
# [CV] END colsample_bytree=0.9, learning_rate=0.01, max_depth=5, n_estimators=200; total time=   0.2s
# [CV] END colsample_bytree=0.9, learning_rate=0.01, max_depth=5, n_estimators=500; total time=   0.5s
# [CV] END colsample_bytree=0.9, learning_rate=0.01, max_depth=5, n_estimators=1000; total time=   0.9s
# [CV] END colsample_bytree=0.9, learning_rate=0.01, max_depth=6, n_estimators=500; total time=   0.5s
# [CV] END colsample_bytree=0.9, learning_rate=0.01, max_depth=6, n_estimators=1000; total time=   1.1s
# [CV] END colsample_bytree=0.9, learning_rate=0.5, max_depth=2, n_estimators=500; total time=   0.3s
# [CV] END colsample_bytree=0.9, learning_rate=0.5, max_depth=2, n_estimators=1000; total time=   0.5s
# [CV] END colsample_bytree=0.9, learning_rate=0.5, max_depth=3, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.9, learning_rate=0.5, max_depth=3, n_estimators=1000; total time=   0.4s
# [CV] END colsample_bytree=0.9, learning_rate=0.5, max_depth=4, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.9, learning_rate=0.5, max_depth=4, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.9, learning_rate=0.5, max_depth=4, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.9, learning_rate=0.5, max_depth=4, n_estimators=500; total time=   0.2s
# [CV] END colsample_bytree=0.9, learning_rate=0.5, max_depth=5, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.9, learning_rate=0.5, max_depth=5, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.9, learning_rate=0.5, max_depth=5, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.9, learning_rate=0.5, max_depth=5, n_estimators=200; total time=   0.2s
# [CV] END colsample_bytree=0.9, learning_rate=0.5, max_depth=5, n_estimators=500; total time=   0.3s
# [CV] END colsample_bytree=0.9, learning_rate=0.5, max_depth=6, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.9, learning_rate=0.5, max_depth=6, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.9, learning_rate=0.5, max_depth=6, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=0.9, learning_rate=0.5, max_depth=6, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=0.9, learning_rate=0.5, max_depth=6, n_estimators=500; total time=   0.3s
# [CV] END colsample_bytree=0.9, learning_rate=0.5, max_depth=6, n_estimators=1000; total time=   0.4s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=2, n_estimators=500; total time=   0.3s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=2, n_estimators=1000; total time=   0.6s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=3, n_estimators=500; total time=   0.4s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=3, n_estimators=1000; total time=   0.8s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=4, n_estimators=500; total time=   0.4s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=4, n_estimators=1000; total time=   0.9s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=5, n_estimators=1000; total time=   0.9s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=6, n_estimators=100; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=6, n_estimators=200; total time=   0.3s
# [CV] END colsample_bytree=1, learning_rate=0.1, max_depth=6, n_estimators=500; total time=   0.6s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=2, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=2, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=2, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=2, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=2, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=2, n_estimators=500; total time=   0.3s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=2, n_estimators=1000; total time=   0.6s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=3, n_estimators=200; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=3, n_estimators=500; total time=   0.4s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=4, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=4, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=4, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=4, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=4, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=4, n_estimators=200; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=4, n_estimators=200; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=4, n_estimators=1000; total time=   0.9s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=5, n_estimators=100; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=5, n_estimators=200; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=5, n_estimators=200; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=5, n_estimators=1000; total time=   1.1s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=6, n_estimators=200; total time=   0.2s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=6, n_estimators=500; total time=   0.6s
# [CV] END colsample_bytree=1, learning_rate=0.01, max_depth=6, n_estimators=1000; total time=   1.3s
# [CV] END colsample_bytree=1, learning_rate=0.5, max_depth=2, n_estimators=1000; total time=   0.5s
# [CV] END colsample_bytree=1, learning_rate=0.5, max_depth=3, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.5, max_depth=3, n_estimators=500; total time=   0.3s
# [CV] END colsample_bytree=1, learning_rate=0.5, max_depth=3, n_estimators=1000; total time=   0.4s
# [CV] END colsample_bytree=1, learning_rate=0.5, max_depth=4, n_estimators=200; total time=   0.1s
# [CV] END colsample_bytree=1, learning_rate=0.5, max_depth=4, n_estimators=500; total time=   0.3s
# GridSearchCV(cv=10,
#              estimator=XGBRegressor(base_score=None, booster=None,
#                                     callbacks=None, colsample_bylevel=None,
#                                     colsample_bynode=None,
#                                     colsample_bytree=None,
#                                     early_stopping_rounds=None,
#                                     enable_categorical=False, eval_metric=None,
#                                     feature_types=None, gamma=None, gpu_id=None,
#                                     grow_policy=None, importance_type=None,
#                                     interaction_constraints=None,
#                                     learning_rate=None,...
#                                     max_cat_to_onehot=None, max_delta_step=None,
#                                     max_depth=None, max_leaves=None,
#                                     min_child_weight=None, missing=nan,
#                                     monotone_constraints=None, n_estimators=100,
#                                     n_jobs=None, num_parallel_tree=None,
#                                     predictor=None, random_state=None, ...),
#              n_jobs=-1,
#              param_grid={'colsample_bytree': [0.4, 0.5, 0.6, 0.9, 1],
#                          'learning_rate': [0.1, 0.01, 0.5],
#                          'max_depth': [2, 3, 4, 5, 6],
#                          'n_estimators': [100, 200, 500, 1000]},
#              verbose=2)

# %%
xgb_cv.best_params_
# Out:
# {'colsample_bytree': 0.6,
#  'learning_rate': 0.1,
#  'max_depth': 2,
#  'n_estimators': 1000}

# %%
xgb_tuned = XGBRegressor(colsample_bytree = 0.9,
                         learning_rate = 0.01,
                         max_depth = 5,
                         n_estimators = 1000)

xgb_tuned = xgb_tuned.fit(X_train,y_train)

# %%
y_pred = xgb_tuned.predict(X_test)
np.sqrt(mean_squared_error(y_test, y_pred))
# Out:
# 357.18507083923674
